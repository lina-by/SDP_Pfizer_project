# %%
from epsilon_constraints import epsilon_constraints
from objective_functions import disruption, distance
from plots import plot_cities_attribution

import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # STEP 1

# %% [markdown]
# ### Load the 22 Bricks and 4 SRs instance

# %%
distances = pd.read_excel('data/distances.xlsx')
distances = distances.drop(distances.columns[0], axis=1)
distances.columns = range(len(distances.columns))

index_values = pd.read_csv("data/bricks_index_values.csv")['index_value']

num_zones = 22
num_SRs = 4

current_assignment = {
    0: {"Center brick": 3, "Assigned bricks": [3, 4, 5, 6, 7, 14]},
    1: {"Center brick": 13, "Assigned bricks": [9, 10, 11, 12, 13]},
    2: {"Center brick": 15, "Assigned bricks": [8, 15, 16, 17]},
    3: {"Center brick": 21, "Assigned bricks": [0, 1, 2, 18, 19, 20, 21]}
}

# %% [markdown]
# ### Solutions with a workload in the interval [0.8, 1.2]

# %% [markdown]
# Minimizing the disruption with constraints on the distance

# %%
interval = (0.8, 1.2)

assignments, scores = epsilon_constraints(num_zones=num_zones,
                                          num_SRs=num_SRs,
                                          current_assignment=current_assignment,
                                          distances=distances,
                                          index_values=index_values,
                                          objective_function=disruption,
                                          wl_interval=interval,
                                          epsilon_constraint=distance)

X = [el[0] for el in scores]
y = [el[1] for el in scores]

plt.plot(X, y, marker='o', color='b', linestyle=' ')
plt.xlabel('Disruption')
plt.ylabel('Distance')
plt.title("Minimisation de la Disruption en contraignant la distance, avec un workload entre [0.8, 1.2]")
plt.show()
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2601671
# Academic license - for non-commercial use only - expires 2025-12-18
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# ...

# %%
for i in range(len(assignments)):
    print(f"Attribution avec une distance totale de {round(scores[i][1], 4)} et un workload modifié de {round(scores[i][0], 4)}: ")
    plot_cities_attribution(assignments[i])
# Out:
# Attribution avec une distance totale de 188.89 et un workload modifié de 0.1696:
# c:\Users\linab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# Attribution avec une distance totale de 188.13 et un workload modifié de 0.227:
# c:\Users\linab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# Attribution avec une distance totale de 187.2 et un workload modifié de 0.2529:
# ...

# %% [markdown]
# Minimizing the distance with constraints on the disruption

# %%
interval = (0.8, 1.2)

assignments, scores = epsilon_constraints(num_zones=num_zones, num_SRs=num_SRs, current_assignment=current_assignment,
                                              distances=distances, index_values=index_values, objective_function=distance, wl_interval=interval, epsilon_constraint=disruption)

y = [el[0] for el in scores]
X = [el[1] for el in scores]

plt.plot(X, y, marker='o', color='b', linestyle=' ')
plt.xlabel('Disruption')
plt.ylabel('Distance')
plt.title("Minimisation de la Disruption en contraignant la distance, avec un workload entre [0.8, 1.2]")
plt.show()

# %%
for i in range(len(assignments)):
    print(f"Attribution avec une distance totale de {round(scores[i][0], 4)} et un workload modifié de {round(scores[i][1], 4)}: ")
    plot_cities_attribution(assignments[i])
# Out:
# Attribution avec une distance totale de 154.62 et un workload modifié de 1.2055:
# c:\Users\linab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# Attribution avec une distance totale de 154.64 et un workload modifié de 1.1227:
# c:\Users\linab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# Attribution avec une distance totale de 154.99 et un workload modifié de 0.9967:
# ...

# %% [markdown]
# ### Solutions with a workload in the interval [0.85, 1.15]
# Minimizing the disruption with constraints on the distance

# %%
interval = (0.85, 1.15
            )

assignments, scores = epsilon_constraints(num_zones=num_zones, num_SRs=num_SRs, current_assignment=current_assignment,
                                              distances=distances, index_values=index_values, objective_function=disruption, wl_interval=interval, epsilon_constraint=distance)

X = [el[0] for el in scores]
y = [el[1] for el in scores]

plt.plot(X, y, marker='o', color='b', linestyle=' ')
plt.xlabel('Disruption')
plt.ylabel('Distance')
plt.title("Minimisation de la Disruption en contraignant la distance, avec un workload entre [0.8, 1.2]")
plt.show()
# Out:
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored

# %%
for i in range(len(assignments)):
    print(f"Attribution avec une distance totale de {round(scores[i][1], 4)} et un workload modifié de {round(scores[i][0], 4)}: ")
    plot_cities_attribution(assignments[i])
# Out:
# Attribution avec une distance totale de 187.2 et un workload modifié de 0.2529:
# c:\Users\linab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# Attribution avec une distance totale de 186.43 et un workload modifié de 0.2956:
# c:\Users\linab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# Attribution avec une distance totale de 181.48 et un workload modifié de 0.3526:
# ...

# %% [markdown]
# ### Solutions with a workload in the interval [0.9, 1.1]
# Minimizing the disruption with constraints on the distance

# %%
interval = (0.9, 1.1
            )

assignments, scores = epsilon_constraints(num_zones=num_zones, num_SRs=num_SRs, current_assignment=current_assignment,
                                              distances=distances, index_values=index_values, objective_function=disruption, wl_interval=interval, epsilon_constraint=distance)

X = [el[0] for el in scores]
y = [el[1] for el in scores]

plt.plot(X, y, marker='o', color='b', linestyle=' ')
plt.xlabel('Disruption')
plt.ylabel('Distance')
plt.title("Minimisation de la Disruption en contraignant la distance, avec un workload entre [0.8, 1.2]")
plt.show()
# Out:
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored

# %%
for i in range(len(assignments)):
    print(f"Attribution avec une distance totale de {round(scores[i][1], 4)} et un workload modifié de {round(scores[i][0], 4)}: ")
    plot_cities_attribution(assignments[i])
# Out:
# Attribution avec une distance totale de 187.2 et un workload modifié de 0.2529:
# c:\Users\linab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# Attribution avec une distance totale de 186.66 et un workload modifié de 0.3397:
# c:\Users\linab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# Attribution avec une distance totale de 181.48 et un workload modifié de 0.3526:
# ...

# %% [markdown]
# # STEP 2

# %%
from model import create_model, get_solution_dict
from gurobipy import GRB
import numpy as np

# %%
model = create_model(num_zones=num_zones, num_SRs=num_SRs, current_assignment=current_assignment,
                                              distances=distances, index_values=index_values, objective_function=distance,
                                              wl_interval=interval,
                                              epsilon=1, epsilon_constraint=disruption)
model.params.outputflag = 0
model.optimize()
status = model.status
center_bricks=[3, 13, 15, 21]
if status == GRB.OPTIMAL:
    rebuilded_sol = np.array([[model.getVarByName(f"pct_zone_SR[{i},{j}]").X for j in range(num_SRs)] for i in range(num_zones)])
    assignment = get_solution_dict(model, num_zones, num_SRs, center_bricks)

# %%
plot_cities_attribution(assignment)
# Out:
# c:\Users\linab\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
